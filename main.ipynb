# %%
            #############################################################
            #        *********** Prototype 1 *********                  #
            #            Eliodor Ednalson Guy Mirlin                    #
            #                                                           #
            #   Internship : Deduplication using machine Learning       #      
            #                 Orchestra Network                         #
            #############################################################

#This first prototype is using the dedupe library from python to deduplicate a CSV file giving in input

# Input : a CSV file with many duplicate records 
# output : another CSV file generated from the system which has the clustered deduplicate detection results 

#Import of packages et libraries : 
from builtins import next
import dedupe
import os
import csv
import re
from unidecode import unidecode
import pandas as pd

# %%
# setting up of the system : input, output, settings, training
#Input : The CSV filename which contains the duplicated records
#output : The CSV file generated from the system which list the cluters of the deduplicate detection
#system : this file contains the data model ie the format of the data before the training process
# training : this file in .Json save the training set before starting the clustering process

input_file = 'restaurant.csv'
output_file = 'deduplicationRestaurant1.csv'
settings_file = 'settings'
training_file = 'training.json'

# %%
# This function preProcess is using for Data cleaning by using Unidecode. 
#Quotes,empty lines and unapropriate spaces are ignored

def preProcess(column):
    
    try : # python 2/3 string differences
        column = column.decode('utf8')
    except AttributeError:
        pass
    column = unidecode(column)
    column = re.sub('  +', ' ', column)
    column = re.sub('\n', ' ', column)
    column = column.strip().strip('"').strip("'").lower().strip()
    if not column:
        column = None
    return column

# %%
def readData(filename):
    """
    Read in the data from a CSV file and created a dictionary of records, 
    where the key is a unique record ID and each value is dict
    """

    data_d = {}
    with open(filename, 'rU') as f:
        reader = csv.DictReader(f)
        ide = 0
        for row in reader:
            clean_row = [(k, preProcess(v)) for (k, v) in row.items()]
            row_id = ide
            data_d[row_id] = dict(clean_row)
            ide= ide + 1

    return data_d

# %%
print('Import and listing ... \n')
data_d = readData(input_file)

dframe = pd.read_table('restaurant.csv', sep=',')
dframe
# Out:
# Import and listing ...
# /home/orchestra/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:8: DeprecationWarning: 'U' mode is deprecated
#                                         NAME  \
# 0                             Apple Pan  The
# 1                  Arnie Morton's of Chicago
# 2                                 Art's Deli
# 3                                Asahi Ramen
# 4                                 Baja Fresh
# 5                              Bel-Air Hotel
# 6                             Belvedere  The
# 7                            Benita's Frites
# 8                                  Bernard's
# 9                                  Bistro 45
# 10                              Brent's Deli
# 11                      Brighton Coffee Shop
# 12                 Bristol Farms Market Cafe
# 13                                   Bruno's
# 14                                 Cafe '50s
# 15                                Cafe Bizou
# 16                                Cafe Blanc
# 17                                 Campanile
# 18                                 Cassell's
# 19                              Chez Melange
# 20                           Chinois on Main
# 21                                    Citrus
# 22                                 Diaghilev
# 23                             Don Antonio's
# 24                                    Duke's
# 25                              Falafel King
# 26                       Feast from the East
# 27                       Fenix at the Argyle
# 28                                   Granita
# 29                                Grill  The
# ..                                       ...
# 835                                  Postrio
# 836                               R&G Lounge
# 837  Ritz-Carlton Restaurant and Dining Room
# 838                             Rose Pistola
# 839                                  Rubicon
# 840                                   Rumpus
# 841                                   Sanppo
# 842                           Scala's Bistro
# 843                          South Park Cafe
# 844                    Splendido Embarcadero
# 845                                    Stars
# 846                               Stars Cafe
# 847                          Stoyanof's Cafe
# 848                             Straits Cafe
# 849                              Suppenkuche
# 850                             Tadich Grill
# 851                              The Heights
# 852                                   Thepin
# 853                                Ton Kiang
# 854                                  Vertigo
# 855                        Vivande Porta Via
# 856                       Vivande Ristorante
# 857                             World Wrapps
# 858                                  Wu Kong
# 859                                Yank Sing
# 860                             Yaya Cuisine
# 861                      Yoyo Tsumami Bistro
# 862                                 Zarzuela
# 863                        Zuni Cafe & Grill
# 864
#
#                                            ADDRESS  \
# 0                      10801 W. Pico Blvd. West LA
# 1              435 S. La Cienega Blvd. Los Angeles
# 2                  12224 Ventura Blvd. Studio City
# 3                      2027 Sawtelle Blvd. West LA
# 4                 3345 Kimber Dr. Westlake Village
# 5                     701 Stone Canyon Rd. Bel Air
# 6     9882 Little Santa Monica Blvd. Beverly Hills
# 7            1433 Third St. Promenade Santa Monica
# 8                     515 S. Olive St. Los Angeles
# 9                       45 S. Mentor Ave. Pasadena
# 10                 19565 Parthenia Ave. Northridge
# 11                 9600 Brighton Way Beverly Hills
# 12                 1570 Rosecrans Ave. S. Pasadena
# 13                   3838 Centinela Ave. Mar Vista
# 14                        838 Lincoln Blvd. Venice
# 15                14016 Ventura Blvd. Sherman Oaks
# 16    9777 Little Santa Monica Blvd. Beverly Hills
# 17                 624 S. La Brea Ave. Los Angeles
# 18                            3266 W. Sixth St. LA
# 19                          1716 PCH Redondo Beach
# 20                      2709 Main St. Santa Monica
# 21                   6703 Melrose Ave. Los Angeles
# 22          1020 N. San Vicente Blvd. W. Hollywood
# 23                    1136 Westwood Blvd. Westwood
# 24                  8909 Sunset Blvd. W. Hollywood
# 25                      1059 Broxton Ave. Westwood
# 26                     1949 Westwood Blvd. West LA
# 27                  8358 Sunset Blvd. W. Hollywood
# 28                      23725 W. Malibu Rd. Malibu
# 29                   9560 Dayton Way Beverly Hills
# ..                                             ...
# 835                     545 Post St. San Francisco
# 836                 631 B Kearny St. San Francisco
# 837                 600 Stockton St. San Francisco
# 838                532 Columbus Ave. San Francisco
# 839               558 Sacramento St. San Francisco
# 840                    1 Tillman Pl. San Francisco
# 841                    1702 Post St. San Francisco
# 842                   432 Powell St. San Francisco
# 843                   108 South Park San Francisco
# 844                                4 San Francisco
# 845                150 Redwood Alley San Francisco
# 846                500 Van Ness Ave. San Francisco
# 847                    1240 9th Ave. San Francisco
# 848                 3300 Geary Blvd. San Francisco
# 849                    601 Hayes St. San Francisco
# 850               240 California St. San Francisco
# 851              3235 Sacramento St. San Francisco
# 852                    298 Gough St. San Francisco
# 853                 3148 Geary Blvd. San Francisco
# 854               600 Montgomery St. San Francisco
# 855                2125 Fillmore St. San Francisco
# 856             670 Golden Gate Ave. San Francisco
# 857                2257 Chestnut St. San Francisco
# 858                    101 Spear St. San Francisco
# 859                  427 Battery St. San Francisco
# 860                    1220 9th Ave. San Francisco
# 861                    1611 Post St. San Francisco
# 862                    2000 Hyde St. San Francisco
# 863                  1658 Market St. San Francisco
# 864                                            NaN
#
#                              PHONE                          CUISINE
# 0                     310-475-3585                         American
# 1                     310-246-1501                      Steakhouses
# 2                     818-762-1221                            Delis
# 3                     310-479-2231                     Noodle Shops
# 4                     805-498-4049                          Mexican
# 5                     310-472-1211                      Californian
# 6                     310-788-2306                 Pacific New Wave
# 7                     310-458-2889                        Fast Food
# 8                     213-612-1580                      Continental
# 9                     818-795-2478                      Californian
# 10                    818-886-5679                            Delis
# 11                    310-276-7732                     Coffee Shops
# 12                    310-643-5229                      Californian
# 13                    310-397-5703                          Italian
# 14                    310-399-1955                         American
# 15                    818-788-3536                    French Bistro
# 16                    310-888-0108                 Pacific New Wave
# 17                    213-938-1447                      Californian
# 18                    213-480-8668                       Hamburgers
# 19                    310-540-1222                         Eclectic
# 20                    310-392-9025                 Pacific New Wave
# 21                    213-857-0034                      Californian
# 22                    310-854-1111                          Russian
# 23                    310-209-1422                          Italian
# 24                    310-652-3100                     Coffee Shops
# 25                    310-208-4444                   Middle Eastern
# 26                    310-475-0400                          Chinese
# 27                    213-848-6677                     French (New)
# 28                    310-456-0488                      Californian
# 29                    310-276-0615           American (Traditional)
# ..                             ...                              ...
# 835                   415-776-7825                         American
# 836   415-982-7877 or 415-982-3811                            Asian
# 837                   415-296-7465                         American
# 838                   415-399-0499                          Italian
# 839                   415-434-4100                         American
# 840                   415-421-2300                         American
# 841                   415-346-3486                            Asian
# 842                   415-395-8555                          Italian
# 843                   415-495-7275                           French
# 844                   415-986-3222                    Mediterranean
# 845                   415-861-7827                         American
# 846                   415-861-4344                         American
# 847                   415-664-3664         Greek and Middle Eastern
# 848                   415-668-1783                            Asian
# 849                   415-252-9289                   Russian-German
# 850                   415-391-2373                          Seafood
# 851                   415-474-8890                           French
# 852                   415-863-9335                            Asian
# 853                   415-752-4440                            Asian
# 854                   415-433-7250                    Mediterranean
# 855                   415-346-4430                          Italian
# 856                   415-673-9245                          Italian
# 857                   415-563-9727                         American
# 858                   415-957-9300                            Asian
# 859                   415-541-4949                            Asian
# 860                   415-566-6966         Greek and Middle Eastern
# 861                   415-922-7788                           French
# 862                   415-346-0800   Mexican-Latin American-Spanish
# 863                   415-552-2522                    Mediterranean
# 864                            NaN                              NaN
#
# [865 rows x 4 columns]

# %%
# If a settings file already exists, we'll just load that and skip training
if os.path.exists(settings_file):
    print('reading from', settings_file)
    with open(settings_file, 'rb') as f:
        deduper = dedupe.StaticDedupe(f)
else:
    # ## Training

    # Define the fields it will pay attention to
    fields = [
        {'field' : 'NAME', 'type': 'String'},
        ]

    # Created a new object and passed our data model to it.
    deduper = dedupe.Dedupe(fields)

    # For training, I feed it a sample of records.
    deduper.sample(data_d)

      # If we have training data saved from a previous run,
  # look for it and load it in.
    if os.path.exists(training_file):
        print('reading labeled examples from ', training_file)
        with open(training_file, 'rb') as f:
            deduper.readTraining(f)

# %%
# ## Active learning
    # will find the next pair of records
    # it is least certain about and ask you to label them as duplicates
    # or not.
    # use 'y', 'n' and 'u' keys to flag duplicates
    # press 'f' when you are finished
print('starting active labeling...')

dedupe.consoleLabel(deduper)

    # Using the examples we just labeled, train it and learn
    # blocking predicates
deduper.train()

    # save our training to disk
with open(training_file, 'w') as tf:
    deduper.writeTraining(tf)

    # Save our weights and predicates to disk.  If the settings file
    # exists, we will skip all the training and learning next time we run
    # this file.
with open(settings_file, 'wb') as sf:
    deduper.writeSettings(sf)
# Out:
# NAME : cafe des artistes
#
# NAME : cafe des artistes
#
# 0/10 positive, 0/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished
# starting active labeling...
# y
# NAME : ocean star
#
# NAME : oceana
#
# 1/10 positive, 0/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# n
# INFO:dedupe.training:Final predicate set:
# INFO:dedupe.training:(SimplePredicate: (commonThreeTokens, NAME), SimplePredicate: (wholeFieldPredicate, NAME))
# NAME : brothers
#
# NAME : broiler
#
# 1/10 positive, 1/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# n
# NAME : bone's restaurant
#
# NAME : bone's
#
# 1/10 positive, 2/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# y
# NAME : second avenue deli
#
# NAME : second avenue deli
#
# 2/10 positive, 2/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# y
# INFO:dedupe.training:Final predicate set:
# INFO:dedupe.training:(TfidfNGramCanopyPredicate: (0.2, NAME), TfidfTextCanopyPredicate: (0.8, NAME))
# NAME : local nochol
#
# NAME : None
#
# 3/10 positive, 2/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# u
# NAME : aquavit
#
# NAME : aqua
#
# 3/10 positive, 2/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# n
# NAME : joe's
#
# NAME : joe's shanghai
#
# 3/10 positive, 3/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# n
# NAME : ritz-carlton dining room (buckhead)
#
# NAME : dining room ritz-carlton buckhead
#
# 3/10 positive, 4/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# y
# NAME : bel-air hotel
#
# NAME : hotel bel-air
#
# 4/10 positive, 4/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# y
# NAME : jack sprat's grill
#
# NAME : judson grill
#
# 5/10 positive, 4/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# n
# NAME : fifty seven fifty seven
#
# NAME : les celebrites
#
# 5/10 positive, 5/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# n
# NAME : coco loco
#
# NAME : splendido embarcadero
#
# 5/10 positive, 6/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# n
# NAME : carnegie deli
#
# NAME : carnegie deli
#
# 5/10 positive, 7/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# y
# NAME : la caravelle
#
# NAME : la caravelle
#
# 6/10 positive, 7/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# y
# NAME : greenwood's
#
# NAME : greens
#
# 7/10 positive, 7/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# n
# NAME : coyote cafe (las vegas)
#
# NAME : coyote cafe
#
# 7/10 positive, 8/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# y
# NAME : sofi
#
# NAME : sofia fabulous pizza
#
# 8/10 positive, 8/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# n
# INFO:dedupe.training:Final predicate set:
# INFO:dedupe.training:(TfidfTextCanopyPredicate: (0.4, NAME), TfidfTextCanopyPredicate: (0.6, NAME))
# NAME : rainbow room
#
# NAME : rainbow restaurant
#
# 8/10 positive, 9/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# n
# NAME : ritz-carlton cafe (buckhead)
#
# NAME : ritz-carlton restaurant
#
# 8/10 positive, 10/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# y
# NAME : aquavit
#
# NAME : aqua
#
# 9/10 positive, 10/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# n
# NAME : pacifica
#
# NAME : pacific pan pacific hotel
#
# 9/10 positive, 11/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# n
# NAME : california pizza kitchen
#
# NAME : None
#
# 9/10 positive, 12/10 negative
# Do these records refer to the same thing?
# (y)es / (n)o / (u)nsure / (f)inished / (p)revious
# f
# Finished labeling
# INFO:rlr.crossvalidation:using cross validation to find optimum alpha...
# INFO:rlr.crossvalidation:optimum alpha: 0.100000, score 0.004802585034933624
# INFO:dedupe.training:Final predicate set:
# INFO:dedupe.training:(TfidfTextCanopyPredicate: (0.4, NAME), TfidfTextCanopyPredicate: (0.6, NAME))

# %%
# Find the threshold that will maximize a weighted average of our
# precision and recall.  When we set the recall weight to 2, we are
# saying we care twice as much about recall as we do precision.
#
# If we had more data, we would not pass in all the blocked data into
# this function but a representative sample.

threshold = deduper.threshold(data_d, recall_weight=1)

# ## Clustering

# `match` will return sets of record IDs that it
# believes are all referring to the same entity.

print('clustering...')
clustered_dupes = deduper.match(data_d, threshold)

print('# duplicate sets', len(clustered_dupes))

# ## Writing Results

# Write our original data back out to a CSV with a new column called 
# 'Cluster ID' which indicates which records refer to each other.

cluster_membership = {}
cluster_id = 0
for (cluster_id, cluster) in enumerate(clustered_dupes):
    id_set, scores = cluster
    cluster_d = [data_d[c] for c in id_set]
    canonical_rep = dedupe.canonicalize(cluster_d)
    for record_id, score in zip(id_set, scores):
        cluster_membership[record_id] = {
            "cluster id" : cluster_id,
            "canonical representation" : canonical_rep,
            "confidence": score
        }

singleton_id = cluster_id + 1

with open(output_file, 'w') as f_output, open(input_file , 'rU') as f_input:
    writer = csv.writer(f_output)
    reader = csv.reader(f_input)

    heading_row = next(reader)
    heading_row.insert(0, 'confidence_score')
    heading_row.insert(0, 'Cluster ID')
    canonical_keys = canonical_rep.keys()
    for key in canonical_keys:
        heading_row.append('canonical_' + key)

    writer.writerow(heading_row)
    ide = 0
    for row in reader:
        row_id = ide
        if row_id in cluster_membership:
            cluster_id = cluster_membership[row_id]["cluster id"]
            canonical_rep = cluster_membership[row_id]["canonical representation"]
            row.insert(0, cluster_membership[row_id]['confidence'])
            row.insert(0, cluster_id)
            for key in canonical_keys:
                row.append(canonical_rep[key].encode('utf8'))
        else:
            row.insert(0, None)
            row.insert(0, singleton_id)
            singleton_id += 1
            for key in canonical_keys:
                row.append(None)
        writer.writerow(row)
        ide= ide + 1
# Out:
# INFO:dedupe.api:Maximum expected recall and precision
# INFO:dedupe.api:recall: 1.000
# INFO:dedupe.api:precision: 0.446
# INFO:dedupe.api:With threshold: 0.322
# clustering...
# # duplicate sets 117
# /home/orchestra/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:40: DeprecationWarning: 'U' mode is deprecated

# %%
print("Results of the deduplicated detection after training")
dframe = pd.read_table('Deduplicationoutput3.csv', sep=',')
dframe.sort_values(by=['Cluster ID'])
# Out:
# Results of the deduplicated detection after training
#      Cluster ID  confidence_score   ID Date_received                  Product  \
# 0             0          0.897717    1    2016-05-18                 Mortgage
# 174           0          0.897717  175    2013-02-16  Bank account or service
# 168           0          0.897717  169    2012-04-27                 Mortgage
# 593           0          0.897717  594    2014-05-04                 Mortgage
# 600           0          0.897717  601    2013-03-30            Consumer Loan
# 148           0          0.897717  149    2012-05-17  Bank account or service
# 618           0          0.897717  619    2016-05-17                 Mortgage
# 140           0          0.897717  141    2012-12-19                 Mortgage
# 623           0          0.897717  624    2015-01-14                 Mortgage
# 635           0          0.897717  636    2015-02-23                 Mortgage
# 636           0          0.897717  637    2017-02-17  Bank account or service
# 641           0          0.897717  642    2016-01-28  Bank account or service
# 128           0          0.897717  129    2015-06-02                 Mortgage
# 646           0          0.897717  647    2012-08-17                 Mortgage
# 542           0          0.897717  543    2013-11-20                 Mortgage
# 125           0          0.897717  126    2013-03-27                 Mortgage
# 677           0          0.897717  678    2016-11-22                 Mortgage
# 700           0          0.897717  701    2014-08-05  Other financial service
# 703           0          0.897717  704    2014-05-06                 Mortgage
# 710           0          0.897717  711    2014-08-16                 Mortgage
# 98            0          0.897717   99    2013-04-16                 Mortgage
# 736           0          0.897717  737    2015-11-24  Bank account or service
# 743           0          0.897717  744    2012-11-23                 Mortgage
# 755           0          0.897717  756    2013-03-07             Student loan
# 757           0          0.897717  758    2015-02-03                 Mortgage
# 760           0          0.897717  761    2017-01-11                 Mortgage
# 779           0          0.897717  780    2013-01-08                 Mortgage
# 80            0          0.897717   81    2016-09-01                 Mortgage
# 789           0          0.897717  790    2014-01-09  Bank account or service
# 122           0          0.897717  123    2012-01-06              Credit card
# ..          ...               ...  ...           ...                      ...
# 814         272               NaN  815    2016-02-18          Debt collection
# 819         273               NaN  820    2013-10-17          Debt collection
# 835         274               NaN  836    2015-02-25          Debt collection
# 838         275               NaN  839    2013-08-29         Credit reporting
# 845         276               NaN  846    2015-04-15            Consumer Loan
# 851         277               NaN  852    2016-10-29          Debt collection
# 869         278               NaN  870    2014-12-30                 Mortgage
# 876         279               NaN  877    2014-10-15                 Mortgage
# 877         280               NaN  878    2016-11-21          Debt collection
# 878         281               NaN  879    2016-02-14          Debt collection
# 879         282               NaN  880    2014-02-26          Debt collection
# 889         283               NaN  890    2015-10-22          Debt collection
# 890         284               NaN  891    2013-11-07          Debt collection
# 893         285               NaN  894    2014-04-28          Debt collection
# 894         286               NaN  895    2016-10-19          Debt collection
# 895         287               NaN  896    2016-01-05          Debt collection
# 897         288               NaN  898    2016-01-14            Consumer Loan
# 923         289               NaN  924    2014-04-13          Debt collection
# 931         290               NaN  932    2017-03-28             Student loan
# 937         291               NaN  938    2016-03-02          Debt collection
# 948         292               NaN  949    2012-08-31                 Mortgage
# 951         293               NaN  952    2013-10-29          Debt collection
# 953         294               NaN  954    2014-04-04                 Mortgage
# 956         295               NaN  957    2016-10-25          Debt collection
# 961         296               NaN  962    2015-04-01                 Mortgage
# 970         297               NaN  971    2016-02-05          Debt collection
# 979         298               NaN  980    2014-05-13             Student loan
# 982         299               NaN  983    2016-01-24          Debt collection
# 987         300               NaN  988    2016-08-04          Debt collection
# 988         301               NaN  989    2014-11-28          Debt collection
#
#                                Sub-product  \
# 0                           Other mortgage
# 174                       Checking account
# 168                         Other mortgage
# 593                            VA mortgage
# 600                Personal line of credit
# 148                        Savings account
# 618                           FHA mortgage
# 140                         Other mortgage
# 623                         Other mortgage
# 635            Conventional fixed mortgage
# 636                       Checking account
# 641             Other bank product/service
# 128                         Other mortgage
# 646                         Other mortgage
# 542            Conventional fixed mortgage
# 125                         Other mortgage
# 677                         Other mortgage
# 700                          Check cashing
# 703                         Other mortgage
# 710            Conventional fixed mortgage
# 98                          Other mortgage
# 736                       Checking account
# 743            Conventional fixed mortgage
# 755               Non-federal student loan
# 757            Conventional fixed mortgage
# 760            Conventional fixed mortgage
# 779                         Other mortgage
# 80                             VA mortgage
# 789                       Checking account
# 122                                    NaN
# ..                                     ...
# 814  Other (i.e. phone, health club, etc.)
# 819                            Credit card
# 835                                Medical
# 838                                    NaN
# 845                           Vehicle loan
# 851  Other (i.e. phone, health club, etc.)
# 869                         Other mortgage
# 876                       Reverse mortgage
# 877                                Medical
# 878                            Credit card
# 879                            Payday loan
# 889  Other (i.e. phone, health club, etc.)
# 890                            Credit card
# 893                                Medical
# 894  Other (i.e. phone, health club, etc.)
# 895                          I do not know
# 897                       Installment loan
# 923                                   Auto
# 931               Non-federal student loan
# 937  Other (i.e. phone, health club, etc.)
# 948     Home equity loan or line of credit
# 951  Other (i.e. phone, health club, etc.)
# 953            Conventional fixed mortgage
# 956  Other (i.e. phone, health club, etc.)
# 961            Conventional fixed mortgage
# 970  Other (i.e. phone, health club, etc.)
# 979               Non-federal student loan
# 982                   Federal student loan
# 987                                Medical
# 988                                Medical
#
#                                         Issue  \
# 0    Loan modification,collection,foreclosure
# 174   Account opening, closing, or management
# 168  Loan modification,collection,foreclosure
# 593  Loan servicing, payments, escrow account
# 600               Managing the line of credit
# 148   Account opening, closing, or management
# 618  Loan modification,collection,foreclosure
# 140  Loan modification,collection,foreclosure
# 623  Loan modification,collection,foreclosure
# 635  Loan servicing, payments, escrow account
# 636  Making/receiving payments, sending money
# 641                  Deposits and withdrawals
# 128                                     Other
# 646  Application, originator, mortgage broker
# 542  Loan modification,collection,foreclosure
# 125  Loan modification,collection,foreclosure
# 677  Loan modification,collection,foreclosure
# 700       Customer service/Customer relations
# 703  Loan modification,collection,foreclosure
# 710  Loan servicing, payments, escrow account
# 98   Loan modification,collection,foreclosure
# 736                  Deposits and withdrawals
# 743  Loan modification,collection,foreclosure
# 755                        Repaying your loan
# 757  Loan modification,collection,foreclosure
# 760  Loan modification,collection,foreclosure
# 779  Loan modification,collection,foreclosure
# 80   Loan servicing, payments, escrow account
# 789                  Deposits and withdrawals
# 122       Unsolicited issuance of credit card
# ..                                        ...
# 814     Cont'd attempts collect debt not owed
# 819       Improper contact or sharing of info
# 835     Cont'd attempts collect debt not owed
# 838  Unable to get credit report/credit score
# 845              Shopping for a loan or lease
# 851     Cont'd attempts collect debt not owed
# 869  Loan modification,collection,foreclosure
# 876  Loan servicing, payments, escrow account
# 877           Disclosure verification of debt
# 878        False statements or representation
# 879                     Communication tactics
# 889                     Communication tactics
# 890                     Communication tactics
# 893                     Communication tactics
# 894                     Communication tactics
# 895                     Communication tactics
# 897                Managing the loan or lease
# 923     Cont'd attempts collect debt not owed
# 931        Dealing with my lender or servicer
# 937     Cont'd attempts collect debt not owed
# 948  Loan modification,collection,foreclosure
# 951     Cont'd attempts collect debt not owed
# 953  Loan modification,collection,foreclosure
# 956           Disclosure verification of debt
# 961  Loan servicing, payments, escrow account
# 970     Cont'd attempts collect debt not owed
# 979                       Can't repay my loan
# 982           Disclosure verification of debt
# 987     Cont'd attempts collect debt not owed
# 988       Improper contact or sharing of info
#
#                                   Sub-issue  \
# 0                                       NaN
# 174                                     NaN
# 168                                     NaN
# 593                                     NaN
# 600                                     NaN
# 148                                     NaN
# 618                                     NaN
# 140                                     NaN
# 623                                     NaN
# 635                                     NaN
# 636                                     NaN
# 641                                     NaN
# 128                                     NaN
# 646                                     NaN
# 542                                     NaN
# 125                                     NaN
# 677                                     NaN
# 700                                     NaN
# 703                                     NaN
# 710                                     NaN
# 98                                      NaN
# 736                                     NaN
# 743                                     NaN
# 755                                     NaN
# 757                                     NaN
# 760                                     NaN
# 779                                     NaN
# 80                                      NaN
# 789                                     NaN
# 122                                     NaN
# ..                                      ...
# 814                        Debt is not mine
# 819   Talked to a third party about my debt
# 835                        Debt is not mine
# 838  Problem getting report or credit score
# 845                                     NaN
# 851       Debt resulted from identity theft
# 869                                     NaN
# 876                                     NaN
# 877    Not given enough info to verify debt
# 878       Attempted to collect wrong amount
# 879              Frequent or repeated calls
# 889              Frequent or repeated calls
# 890         Threatened to take legal action
# 893              Frequent or repeated calls
# 894              Frequent or repeated calls
# 895              Frequent or repeated calls
# 897                                     NaN
# 923                           Debt was paid
# 931  Received bad information about my loan
# 937                        Debt is not mine
# 948                                     NaN
# 951                        Debt is not mine
# 953                                     NaN
# 956    Not given enough info to verify debt
# 961                                     NaN
# 970                           Debt was paid
# 979      Can't decrease my monthly payments
# 982    Not given enough info to verify debt
# 987                        Debt is not mine
# 988       Contacted me after I asked not to
#
#                           Consumer_complaint_narrative  \
# 0                                                  NaN
# 174                                                NaN
# 168                                                NaN
# 593                                                NaN
# 600                                                NaN
# 148                                                NaN
# 618                                                NaN
# 140                                                NaN
# 623                                                NaN
# 635                                                NaN
# 636  I went to a Wells Fargo branch to deposit a ch...
# 641                                                NaN
# 128                                                NaN
# 646                                                NaN
# 542                                                NaN
# 125                                                NaN
# 677                                                NaN
# 700                                                NaN
# 703                                                NaN
# 710                                                NaN
# 98                                                 NaN
# 736                                                NaN
# 743                                                NaN
# 755                                                NaN
# 757                                                NaN
# 760                                                NaN
# 779                                                NaN
# 80                                                 NaN
# 789                                                NaN
# 122                                                NaN
# ..                                                 ...
# 814  The Collection Agency has no right to contact ...
# 819                                                NaN
# 835                                                NaN
# 838                                                NaN
# 845  Financed a truck the sales contract was never ...
# 851                                                NaN
# 869                                                NaN
# 876                                                NaN
# 877                                                NaN
# 878                                                NaN
# 879                                                NaN
# 889                                                NaN
# 890                                                NaN
# 893                                                NaN
# 894  my dad is XXXX years old. He had an XXXX accou...
# 895                                                NaN
# 897                                                NaN
# 923                                                NaN
# 931                                                NaN
# 937  I was told by XXXX XXXX XXXX XXXX that I could...
# 948                                                NaN
# 951                                                NaN
# 953                                                NaN
# 956  Unknown and I have never had business with thi...
# 961                                                NaN
# 970  I disputed an item on my report because it was...
# 979                                                NaN
# 982                                                NaN
# 987                                                NaN
# 988                                                NaN
#
#                                Company_public_response          ...            \
# 0    Company has responded to the consumer and the ...          ...
# 174                                                NaN          ...
# 168                                                NaN          ...
# 593                                                NaN          ...
# 600                                                NaN          ...
# 148                                                NaN          ...
# 618  Company has responded to the consumer and the ...          ...
# 140                                                NaN          ...
# 623                                                NaN          ...
# 635                                                NaN          ...
# 636  Company has responded to the consumer and the ...          ...
# 641   Company chooses not to provide a public response          ...
# 128   Company chooses not to provide a public response          ...
# 646                                                NaN          ...
# 542                                                NaN          ...
# 125                                                NaN          ...
# 677  Company has responded to the consumer and the ...          ...
# 700                                                NaN          ...
# 703                                                NaN          ...
# 710                                                NaN          ...
# 98                                                 NaN          ...
# 736   Company chooses not to provide a public response          ...
# 743                                                NaN          ...
# 755                                                NaN          ...
# 757                                                NaN          ...
# 760  Company has responded to the consumer and the ...          ...
# 779                                                NaN          ...
# 80   Company has responded to the consumer and the ...          ...
# 789                                                NaN          ...
# 122                                                NaN          ...
# ..                                                 ...          ...
# 814  Company believes it acted appropriately as aut...          ...
# 819                                                NaN          ...
# 835                                                NaN          ...
# 838                                                NaN          ...
# 845  Company believes complaint caused principally ...          ...
# 851  Company believes it acted appropriately as aut...          ...
# 869                                                NaN          ...
# 876                                                NaN          ...
# 877  Company believes it acted appropriately as aut...          ...
# 878  Company believes it acted appropriately as aut...          ...
# 879                                                NaN          ...
# 889   Company chooses not to provide a public response          ...
# 890                                                NaN          ...
# 893                                                NaN          ...
# 894  Company believes it acted appropriately as aut...          ...
# 895                                                NaN          ...
# 897   Company chooses not to provide a public response          ...
# 923                                                NaN          ...
# 931                                                NaN          ...
# 937  Company has responded to the consumer and the ...          ...
# 948                                                NaN          ...
# 951                                                NaN          ...
# 953                                                NaN          ...
# 956                                                NaN          ...
# 961  Company believes it acted appropriately as aut...          ...
# 970  Company can't verify or dispute the facts in t...          ...
# 979                                                NaN          ...
# 982                                                NaN          ...
# 987                                                NaN          ...
# 988                                                NaN          ...
#
#     canonical_State canonical_ZIP_code     canonical_Tags  \
# 0             b'ca'           b'30004'  b'older american'
# 174           b'ca'           b'30004'  b'older american'
# 168           b'ca'           b'30004'  b'older american'
# 593           b'ca'           b'30004'  b'older american'
# 600           b'ca'           b'30004'  b'older american'
# 148           b'ca'           b'30004'  b'older american'
# 618           b'ca'           b'30004'  b'older american'
# 140           b'ca'           b'30004'  b'older american'
# 623           b'ca'           b'30004'  b'older american'
# 635           b'ca'           b'30004'  b'older american'
# 636           b'ca'           b'30004'  b'older american'
# 641           b'ca'           b'30004'  b'older american'
# 128           b'ca'           b'30004'  b'older american'
# 646           b'ca'           b'30004'  b'older american'
# 542           b'ca'           b'30004'  b'older american'
# 125           b'ca'           b'30004'  b'older american'
# 677           b'ca'           b'30004'  b'older american'
# 700           b'ca'           b'30004'  b'older american'
# 703           b'ca'           b'30004'  b'older american'
# 710           b'ca'           b'30004'  b'older american'
# 98            b'ca'           b'30004'  b'older american'
# 736           b'ca'           b'30004'  b'older american'
# 743           b'ca'           b'30004'  b'older american'
# 755           b'ca'           b'30004'  b'older american'
# 757           b'ca'           b'30004'  b'older american'
# 760           b'ca'           b'30004'  b'older american'
# 779           b'ca'           b'30004'  b'older american'
# 80            b'ca'           b'30004'  b'older american'
# 789           b'ca'           b'30004'  b'older american'
# 122           b'ca'           b'30004'  b'older american'
# ..              ...                ...                ...
# 814             NaN                NaN                NaN
# 819             NaN                NaN                NaN
# 835             NaN                NaN                NaN
# 838             NaN                NaN                NaN
# 845             NaN                NaN                NaN
# 851             NaN                NaN                NaN
# 869             NaN                NaN                NaN
# 876             NaN                NaN                NaN
# 877             NaN                NaN                NaN
# 878             NaN                NaN                NaN
# 879             NaN                NaN                NaN
# 889             NaN                NaN                NaN
# 890             NaN                NaN                NaN
# 893             NaN                NaN                NaN
# 894             NaN                NaN                NaN
# 895             NaN                NaN                NaN
# 897             NaN                NaN                NaN
# 923             NaN                NaN                NaN
# 931             NaN                NaN                NaN
# 937             NaN                NaN                NaN
# 948             NaN                NaN                NaN
# 951             NaN                NaN                NaN
# 953             NaN                NaN                NaN
# 956             NaN                NaN                NaN
# 961             NaN                NaN                NaN
# 970             NaN                NaN                NaN
# 979             NaN                NaN                NaN
# 982             NaN                NaN                NaN
# 987             NaN                NaN                NaN
# 988             NaN                NaN                NaN
#
#     canonical_Consumer_consent_provided canonical_Submitted_via  \
# 0                                b'n/a'                  b'web'
# 174                              b'n/a'                  b'web'
# 168                              b'n/a'                  b'web'
# 593                              b'n/a'                  b'web'
# 600                              b'n/a'                  b'web'
# 148                              b'n/a'                  b'web'
# 618                              b'n/a'                  b'web'
# 140                              b'n/a'                  b'web'
# 623                              b'n/a'                  b'web'
# 635                              b'n/a'                  b'web'
# 636                              b'n/a'                  b'web'
# 641                              b'n/a'                  b'web'
# 128                              b'n/a'                  b'web'
# 646                              b'n/a'                  b'web'
# 542                              b'n/a'                  b'web'
# 125                              b'n/a'                  b'web'
# 677                              b'n/a'                  b'web'
# 700                              b'n/a'                  b'web'
# 703                              b'n/a'                  b'web'
# 710                              b'n/a'                  b'web'
# 98                               b'n/a'                  b'web'
# 736                              b'n/a'                  b'web'
# 743                              b'n/a'                  b'web'
# 755                              b'n/a'                  b'web'
# 757                              b'n/a'                  b'web'
# 760                              b'n/a'                  b'web'
# 779                              b'n/a'                  b'web'
# 80                               b'n/a'                  b'web'
# 789                              b'n/a'                  b'web'
# 122                              b'n/a'                  b'web'
# ..                                  ...                     ...
# 814                                 NaN                     NaN
# 819                                 NaN                     NaN
# 835                                 NaN                     NaN
# 838                                 NaN                     NaN
# 845                                 NaN                     NaN
# 851                                 NaN                     NaN
# 869                                 NaN                     NaN
# 876                                 NaN                     NaN
# 877                                 NaN                     NaN
# 878                                 NaN                     NaN
# 879                                 NaN                     NaN
# 889                                 NaN                     NaN
# 890                                 NaN                     NaN
# 893                                 NaN                     NaN
# 894                                 NaN                     NaN
# 895                                 NaN                     NaN
# 897                                 NaN                     NaN
# 923                                 NaN                     NaN
# 931                                 NaN                     NaN
# 937                                 NaN                     NaN
# 948                                 NaN                     NaN
# 951                                 NaN                     NaN
# 953                                 NaN                     NaN
# 956                                 NaN                     NaN
# 961                                 NaN                     NaN
# 970                                 NaN                     NaN
# 979                                 NaN                     NaN
# 982                                 NaN                     NaN
# 987                                 NaN                     NaN
# 988                                 NaN                     NaN
#
#     canonical_Date_sent_to_company canonical_Company_response_to_consumer  \
# 0                    b'2013-01-11'                              b'closed'
# 174                  b'2013-01-11'                              b'closed'
# 168                  b'2013-01-11'                              b'closed'
# 593                  b'2013-01-11'                              b'closed'
# 600                  b'2013-01-11'                              b'closed'
# 148                  b'2013-01-11'                              b'closed'
# 618                  b'2013-01-11'                              b'closed'
# 140                  b'2013-01-11'                              b'closed'
# 623                  b'2013-01-11'                              b'closed'
# 635                  b'2013-01-11'                              b'closed'
# 636                  b'2013-01-11'                              b'closed'
# 641                  b'2013-01-11'                              b'closed'
# 128                  b'2013-01-11'                              b'closed'
# 646                  b'2013-01-11'                              b'closed'
# 542                  b'2013-01-11'                              b'closed'
# 125                  b'2013-01-11'                              b'closed'
# 677                  b'2013-01-11'                              b'closed'
# 700                  b'2013-01-11'                              b'closed'
# 703                  b'2013-01-11'                              b'closed'
# 710                  b'2013-01-11'                              b'closed'
# 98                   b'2013-01-11'                              b'closed'
# 736                  b'2013-01-11'                              b'closed'
# 743                  b'2013-01-11'                              b'closed'
# 755                  b'2013-01-11'                              b'closed'
# 757                  b'2013-01-11'                              b'closed'
# 760                  b'2013-01-11'                              b'closed'
# 779                  b'2013-01-11'                              b'closed'
# 80                   b'2013-01-11'                              b'closed'
# 789                  b'2013-01-11'                              b'closed'
# 122                  b'2013-01-11'                              b'closed'
# ..                             ...                                    ...
# 814                            NaN                                    NaN
# 819                            NaN                                    NaN
# 835                            NaN                                    NaN
# 838                            NaN                                    NaN
# 845                            NaN                                    NaN
# 851                            NaN                                    NaN
# 869                            NaN                                    NaN
# 876                            NaN                                    NaN
# 877                            NaN                                    NaN
# 878                            NaN                                    NaN
# 879                            NaN                                    NaN
# 889                            NaN                                    NaN
# 890                            NaN                                    NaN
# 893                            NaN                                    NaN
# 894                            NaN                                    NaN
# 895                            NaN                                    NaN
# 897                            NaN                                    NaN
# 923                            NaN                                    NaN
# 931                            NaN                                    NaN
# 937                            NaN                                    NaN
# 948                            NaN                                    NaN
# 951                            NaN                                    NaN
# 953                            NaN                                    NaN
# 956                            NaN                                    NaN
# 961                            NaN                                    NaN
# 970                            NaN                                    NaN
# 979                            NaN                                    NaN
# 982                            NaN                                    NaN
# 987                            NaN                                    NaN
# 988                            NaN                                    NaN
#
#     canonical_Timely_response canonical_Consumer_disputed  \
# 0                      b'yes'                       b'no'
# 174                    b'yes'                       b'no'
# 168                    b'yes'                       b'no'
# 593                    b'yes'                       b'no'
# 600                    b'yes'                       b'no'
# 148                    b'yes'                       b'no'
# 618                    b'yes'                       b'no'
# 140                    b'yes'                       b'no'
# 623                    b'yes'                       b'no'
# 635                    b'yes'                       b'no'
# 636                    b'yes'                       b'no'
# 641                    b'yes'                       b'no'
# 128                    b'yes'                       b'no'
# 646                    b'yes'                       b'no'
# 542                    b'yes'                       b'no'
# 125                    b'yes'                       b'no'
# 677                    b'yes'                       b'no'
# 700                    b'yes'                       b'no'
# 703                    b'yes'                       b'no'
# 710                    b'yes'                       b'no'
# 98                     b'yes'                       b'no'
# 736                    b'yes'                       b'no'
# 743                    b'yes'                       b'no'
# 755                    b'yes'                       b'no'
# 757                    b'yes'                       b'no'
# 760                    b'yes'                       b'no'
# 779                    b'yes'                       b'no'
# 80                     b'yes'                       b'no'
# 789                    b'yes'                       b'no'
# 122                    b'yes'                       b'no'
# ..                        ...                         ...
# 814                       NaN                         NaN
# 819                       NaN                         NaN
# 835                       NaN                         NaN
# 838                       NaN                         NaN
# 845                       NaN                         NaN
# 851                       NaN                         NaN
# 869                       NaN                         NaN
# 876                       NaN                         NaN
# 877                       NaN                         NaN
# 878                       NaN                         NaN
# 879                       NaN                         NaN
# 889                       NaN                         NaN
# 890                       NaN                         NaN
# 893                       NaN                         NaN
# 894                       NaN                         NaN
# 895                       NaN                         NaN
# 897                       NaN                         NaN
# 923                       NaN                         NaN
# 931                       NaN                         NaN
# 937                       NaN                         NaN
# 948                       NaN                         NaN
# 951                       NaN                         NaN
# 953                       NaN                         NaN
# 956                       NaN                         NaN
# 961                       NaN                         NaN
# 970                       NaN                         NaN
# 979                       NaN                         NaN
# 982                       NaN                         NaN
# 987                       NaN                         NaN
# 988                       NaN                         NaN
#
#     canonical_Complaint_ID
# 0                 b'10647'
# 174               b'10647'
# 168               b'10647'
# 593               b'10647'
# 600               b'10647'
# 148               b'10647'
# 618               b'10647'
# 140               b'10647'
# 623               b'10647'
# 635               b'10647'
# 636               b'10647'
# 641               b'10647'
# 128               b'10647'
# 646               b'10647'
# 542               b'10647'
# 125               b'10647'
# 677               b'10647'
# 700               b'10647'
# 703               b'10647'
# 710               b'10647'
# 98                b'10647'
# 736               b'10647'
# 743               b'10647'
# 755               b'10647'
# 757               b'10647'
# 760               b'10647'
# 779               b'10647'
# 80                b'10647'
# 789               b'10647'
# 122               b'10647'
# ..                     ...
# 814                    NaN
# 819                    NaN
# 835                    NaN
# 838                    NaN
# 845                    NaN
# 851                    NaN
# 869                    NaN
# 876                    NaN
# 877                    NaN
# 878                    NaN
# 879                    NaN
# 889                    NaN
# 890                    NaN
# 893                    NaN
# 894                    NaN
# 895                    NaN
# 897                    NaN
# 923                    NaN
# 931                    NaN
# 937                    NaN
# 948                    NaN
# 951                    NaN
# 953                    NaN
# 956                    NaN
# 961                    NaN
# 970                    NaN
# 979                    NaN
# 982                    NaN
# 987                    NaN
# 988                    NaN
#
# [1000 rows x 40 columns]
